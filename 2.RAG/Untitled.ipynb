# %%
import pandas as pd
db = pd.read_csv(r"data\flight_status_1000.csv")
db
# Out:
#     AIRLINE_ENGLISH AIRLINE_KOREAN AIRPORT AIR_FLN ARRIVED_ENG ARRIVED_KOR  \
# 0          JEJU AIR           제주항공     CJJ   7C802    CHEONGJU          청주
# 1          JEJU AIR           제주항공     CJJ   7C850    CHEONGJU          청주
# 2          JEJU AIR           제주항공     CJJ   7C852    CHEONGJU          청주
# 3          JEJU AIR           제주항공     CJJ   7C854    CHEONGJU          청주
# 4          JEJU AIR           제주항공     CJJ   7C856    CHEONGJU          청주
# ..              ...            ...     ...     ...         ...         ...
# 995  ASIANA AIRLINE         아시아나항공     GMP  OZ8903        JEJU          제주
# 996  ASIANA AIRLINE         아시아나항공     GMP  OZ8911        JEJU          제주
# 997  ASIANA AIRLINE         아시아나항공     GMP  OZ8913        JEJU          제주
# 998  ASIANA AIRLINE         아시아나항공     GMP  OZ8915        JEJU          제주
# 999  ASIANA AIRLINE         아시아나항공     GMP  OZ8921        JEJU          제주
#
# ...
